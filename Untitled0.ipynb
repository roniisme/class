# %% [markdown]
# <a href="https://colab.research.google.com/github/roniisme/class/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Загружаем датасет, библиотеки и проверяем корректность загрузки**

# %%
import pandas as pd #Импортируем библиотеки
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter('ignore')
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn import metrics
from sklearn.preprocessing import scale
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('churn.csv') #занпужаем данные

# %%
df.head() #проверка на корректность загрузки
# Out:
#                churn  Customer_Age Gender  Dependent_count Education_Level  \
# 0  Existing Customer            45      M                3     High School
# 1  Existing Customer            49      F                5        Graduate
# 2  Existing Customer            51      M                3        Graduate
# 3  Existing Customer            40      F                4     High School
# 4  Existing Customer            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# ...

# %%
df.info() #смотрим на количество колонок, строк в каждой из них и их тип данных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   churn                     10127 non-null  object
#  1   Customer_Age              10127 non-null  int64
#  2   Gender                    10127 non-null  object
#  3   Dependent_count           10127 non-null  int64
#  4   Education_Level           10127 non-null  object
#  5   Marital_Status            10127 non-null  object
#  6   Income_Category           10127 non-null  object
#  7   Card_Category             10127 non-null  object
#  8   Months_on_book            10127 non-null  int64
#  9   Total_Relationship_Count  10127 non-null  int64
#  10  Months_Inactive_12_mon    10127 non-null  int64
#  11  Contacts_Count_12_mon     10127 non-null  int64
#  12  Credit_Limit              10127 non-null  float64
# ...

# %%
df.describe() #Проверка на аномалии
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# count  10127.000000     10127.000000    10127.000000
# mean      46.325960         2.346203       35.928409
# std        8.016814         1.298908        7.986416
# min       26.000000         0.000000       13.000000
# 25%       41.000000         1.000000       31.000000
# 50%       46.000000         2.000000       36.000000
# 75%       52.000000         3.000000       40.000000
# max       73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# ...

# %%
df.duplicated().any() #Проверка на дубликаты
# Out:
# False

# %%
df.isnull().any() #Проверка на пропуски
# Out:
# churn                       False
# Customer_Age                False
# Gender                      False
# Dependent_count             False
# Education_Level             False
# Marital_Status              False
# Income_Category             False
# Card_Category               False
# Months_on_book              False
# Total_Relationship_Count    False
# Months_Inactive_12_mon      False
# Contacts_Count_12_mon       False
# Credit_Limit                False
# Total_Revolving_Bal         False
# Avg_Open_To_Buy             False
# Total_Amt_Chng_Q4_Q1        False
# Total_Trans_Amt             False
# Total_Trans_Ct              False
# Total_Ct_Chng_Q4_Q1         False
# Avg_Utilization_Ratio       False
# dtype: bool

# %%
#Напишем функцию, которая принимает на вход наши данные, кодирует числовыми значениями категориальные признаки
#и возвращает обновленный данные и сами кодировщики
def number_encode_features(init_df):
    result = init_df.copy() #копируем нашу исходную таблицу
    encoders = {}
    for column in result.columns:
        if result.dtypes[column] == np.object: # np.object -- строковый тип / если тип столбца - строка, то нужно его закодировать
            encoders[column] = preprocessing.LabelEncoder() #для колонки column создаем кодировщик
            result[column] = encoders[column].fit_transform(result[column]) #применяем кодировщик к столбцу и перезаписываем столбец
    return result, encoders

encoded_data, encoders = number_encode_features(df) #Теперь encoded data содержит закодированные категориальные признаки
encoded_data.head() #проверяем
# Out:
#    churn  Customer_Age  Gender  Dependent_count  Education_Level  \
# 0      1            45       1                3                3
# 1      1            49       0                5                2
# 2      1            51       1                3                2
# 3      1            40       0                4                3
# 4      1            40       1                3                5
#
#    Marital_Status  Income_Category  Card_Category  Months_on_book  \
# 0               1                2              0              39
# 1               2                4              0              44
# 2               1                3              0              36
# 3               3                4              0              34
# 4               1                2              0              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0                         5                       1                      3
# ...

# %%
df['churn'].value_counts() #очень грустно
#сильный дисбаланс классов
# Out:
# Existing Customer    8500
# Attrited Customer    1627
# Name: churn, dtype: int64

# %%
df.groupby(["Card_Category" , "churn"])["churn"].count() #смотрим как тип карты влияет на уход клиентов
# Out:
# Card_Category  churn
# Blue           Attrited Customer    1519
#                Existing Customer    7917
# Gold           Attrited Customer      21
#                Existing Customer      95
# Platinum       Attrited Customer       5
#                Existing Customer      15
# Silver         Attrited Customer      82
#                Existing Customer     473
# Name: churn, dtype: int64

# %%
df.groupby(["Gender", "churn"])["churn"].count() #пол не особо влияет на наш таргет
# Out:
# Gender  churn
# F       Attrited Customer     930
#         Existing Customer    4428
# M       Attrited Customer     697
#         Existing Customer    4072
# Name: churn, dtype: int64

# %%
df.groupby(["Marital_Status", "churn"])["churn"].count()  #семейный статус не особо влияет на наш таргет
# Out:
# Marital_Status  churn
# Divorced        Attrited Customer     121
#                 Existing Customer     627
# Married         Attrited Customer     709
#                 Existing Customer    3978
# Single          Attrited Customer     668
#                 Existing Customer    3275
# Unknown         Attrited Customer     129
#                 Existing Customer     620
# Name: churn, dtype: int64

# %%
for i in ['Customer_Age', 'Avg_Open_To_Buy', 'Education_Level', 'Months_on_book', 'Dependent_count', 'Income_Category', 'Marital_Status', 'Months_Inactive_12_mon', 'Contacts_Count_12_mon', 'Avg_Utilization_Ratio', 'Total_Relationship_Count']: #в цикл закинули 2 колонки
  Attrited = list(encoded_data[encoded_data['churn'] == 0][i].dropna())
  Existing = list(encoded_data[encoded_data['churn'] == 1][i].dropna())
  xmin = min(min(Attrited), min(Existing))
  xmax = max(max(Attrited), max(Existing))
  width = (xmax - xmin) / 20 #настройка ширины
  sns.distplot(Existing, color='seagreen', kde=False, bins=np.arange(xmin, xmax, width))
  sns.distplot(Attrited, color='black', kde=False, bins=np.arange(xmin, xmax, width))
  plt.legend(['текущий клиент','ушедший клиент'])
  plt.title('Наложенная гистограмма для колонки {}'.format(i))
  plt.show()

# %%
plt.subplots(figsize=(25,25))
encoded_data, encoders = number_encode_features(df)
sns.heatmap(encoded_data.corr(), square=True, annot=True, cmap=sns.cubehelix_palette(start=2, rot=0, dark=0, light=.95, reverse=True, as_cmap=True)) #самую большую взаимосвязь с целевой переменной имеют колонки с Total в названии (данные об общих количествах транзакций,сделок и тд) и средний коэффициент использования карт
# Out:
# <Axes: >

# %%
sns.set_style("darkgrid")
encoded_data.hist(figsize=(20,15), color='seagreen') #смотрим на распределение данных
# Out:
# array([[<Axes: title={'center': 'churn'}>,
#         <Axes: title={'center': 'Customer_Age'}>,
#         <Axes: title={'center': 'Gender'}>,
#         <Axes: title={'center': 'Dependent_count'}>],
#        [<Axes: title={'center': 'Education_Level'}>,
#         <Axes: title={'center': 'Marital_Status'}>,
#         <Axes: title={'center': 'Income_Category'}>,
#         <Axes: title={'center': 'Card_Category'}>],
#        [<Axes: title={'center': 'Months_on_book'}>,
#         <Axes: title={'center': 'Total_Relationship_Count'}>,
#         <Axes: title={'center': 'Months_Inactive_12_mon'}>,
#         <Axes: title={'center': 'Contacts_Count_12_mon'}>],
#        [<Axes: title={'center': 'Credit_Limit'}>,
#         <Axes: title={'center': 'Total_Revolving_Bal'}>,
#         <Axes: title={'center': 'Avg_Open_To_Buy'}>,
#         <Axes: title={'center': 'Total_Amt_Chng_Q4_Q1'}>],
#        [<Axes: title={'center': 'Total_Trans_Amt'}>,
#         <Axes: title={'center': 'Total_Trans_Ct'}>,
# ...

# %%
encoded_data.describe()
# Out:
#               churn  Customer_Age        Gender  Dependent_count  \
# count  10127.000000  10127.000000  10127.000000     10127.000000
# mean       0.839340     46.325960      0.470919         2.346203
# std        0.367235      8.016814      0.499178         1.298908
# min        0.000000     26.000000      0.000000         0.000000
# 25%        1.000000     41.000000      0.000000         1.000000
# 50%        1.000000     46.000000      0.000000         2.000000
# 75%        1.000000     52.000000      1.000000         3.000000
# max        1.000000     73.000000      1.000000         5.000000
#
#        Education_Level  Marital_Status  Income_Category  Card_Category  \
# count     10127.000000    10127.000000     10127.000000   10127.000000
# mean          3.096574        1.463415         2.863928       0.179816
# std           1.834812        0.737808         1.504700       0.693039
# min           0.000000        0.000000         0.000000       0.000000
# ...

# %% [markdown]
# # **Вывод** по анализу:

# %%
df = pd.get_dummies(encoded_data, columns=['Total_Relationship_Count','Months_Inactive_12_mon', 'Contacts_Count_12_mon','Dependent_count', 'Education_Level', 'Income_Category','Card_Category'])  #кодируем оставшиемся нужные кат. колонки
df.head()
# Out:
#    churn  Customer_Age  Gender  Marital_Status  Months_on_book  Credit_Limit  \
# 0      1            45       1               1              39       12691.0
# 1      1            49       0               2              44        8256.0
# 2      1            51       1               1              36        3418.0
# 3      1            40       0               3              34        3313.0
# 4      1            40       1               1              21        4716.0
#
#    Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0                  777          11914.0                 1.335
# 1                  864           7392.0                 1.541
# 2                    0           3418.0                 2.594
# 3                 2517            796.0                 1.405
# 4                    0           4716.0                 2.175
#
#    Total_Trans_Amt  ...  Income_Category_0  Income_Category_1  \
# 0             1144  ...                  0                  0
# ...

# %%
cat_feat = ['Gender', 'Marital_Status',]
df.drop(cat_feat, axis=1, inplace=True)

# %%
df = df.sort_values(by ='churn', ignore_index=True)
df.head()
# Out:
#    churn  Customer_Age  Months_on_book  Credit_Limit  Total_Revolving_Bal  \
# 0      0            43              25       10388.0                 1961
# 1      0            44              36        1905.0                    0
# 2      0            61              49       11374.0                 2517
# 3      0            53              40        1625.0                    0
# 4      0            53              36        2121.0                    0
#
#    Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0           8427.0                 0.703            10294              61
# 1           1905.0                 0.845             3120              46
# 2           8857.0                 1.015             1088              26
# 3           1625.0                 0.689             2314              43
# 4           2121.0                 0.618             1464              32
#
#    Total_Ct_Chng_Q4_Q1  ...  Income_Category_0  Income_Category_1  \
# ...

# %%
df.tail()
# Out:
#        churn  Customer_Age  Months_on_book  Credit_Limit  Total_Revolving_Bal  \
# 10122      1            42              27       11880.0                 2025
# 10123      1            43              37        4188.0                    0
# 10124      1            59              54        9344.0                 1334
# 10125      1            50              41       15641.0                 2379
# 10126      1            51              32        8365.0                 1504
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 10122           9855.0                 0.835             1789              42
# 10123           4188.0                 0.565             3492              69
# 10124           8010.0                 0.375             4154              60
# 10125          13262.0                 0.816             3769              76
# 10126           6861.0                 0.679             4778              88
#
# ...

# %%
test_0 = df[0:500]
test_1 = df[9576:10126]
test = pd.concat([test_1, test_0])
test = test.sort_values(by ='churn', ignore_index=True)
test
# Out:
#       churn  Customer_Age  Months_on_book  Credit_Limit  Total_Revolving_Bal  \
# 0         0            31              20        8149.0                    0
# 1         0            48              36        1641.0                    0
# 2         0            37              26        6866.0                 2389
# 3         0            49              36        8136.0                 2517
# 4         0            41              36        2246.0                    0
# ...     ...           ...             ...           ...                  ...
# 1045      1            49              39        7223.0                 1963
# 1046      1            52              39        1629.0                  978
# 1047      1            44              36       17116.0                 1289
# 1048      1            44              32       28397.0                 1421
# 1049      1            43              31        9662.0                  817
#
# ...

# %%
train = df[500:9576]
train  = train.sort_values(by ='churn', ignore_index=True)
train
# Out:
#       churn  Customer_Age  Months_on_book  Credit_Limit  Total_Revolving_Bal  \
# 0         0            50              42       31782.0                    0
# 1         0            57              43       34516.0                 1847
# 2         0            34              26        2066.0                  347
# 3         0            51              45       25670.0                    0
# 4         0            40              33        5500.0                  442
# ...     ...           ...             ...           ...                  ...
# 9071      1            45              32        5999.0                  658
# 9072      1            52              36        2597.0                 1740
# 9073      1            51              45        1757.0                    0
# 9074      1            49              43       34516.0                 1163
# 9075      1            46              34        9216.0                 2059
#
# ...

# %%
test['churn'].value_counts()
# Out:
# 1    550
# 0    500
# Name: churn, dtype: int64

# %%
train['churn'].value_counts()
# Out:
# 1    7949
# 0    1127
# Name: churn, dtype: int64

# %%
X = np.array(df.drop('churn', axis=1))
y = np.array(df['churn'])

# %%
X_train = np.array(train.drop('churn', axis=1))
y_train = np.array(train['churn'])
X_test = np.array(test.drop('churn', axis=1))
y_test = np.array(test['churn'])

# %%
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix

# %%
"from sklearn.preprocessing import StandardScaler

"scaler = StandardScaler()
"X_test = scaler.fit_transform(X_test)"
"X_train = scaler.fit_transform(X_train)"

# %%
"X_train"

# %%
"X_test"

# %%
logreg = LogisticRegression(class_weight='balanced',  penalty='l2')
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
recall_log = recall_score(y_test, y_pred, average=None) * 100
recall_log
# Out:
# array([77.6       , 85.27272727])

# %%
precision_log = precision_score(y_test, y_pred, average=None) * 100
precision_log
# Out:
# array([82.72921109, 80.72289157])

# %%
confusion_log = confusion_matrix(y_test, y_pred)
confusion_log
# Out:
# array([[388, 112],
#        [ 81, 469]])

# %%
logreg = LogisticRegression(class_weight='balanced', penalty='l2')
print(cross_val_score(logreg, X, y, cv=10, scoring='recall').mean())
# Out:
# 0.7350588235294118

# %%
from sklearn.metrics import classification_report
churn = ['0', '1']
print(classification_report(y_test, y_pred, target_names= churn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.78      0.80       500
#            1       0.81      0.85      0.83       550
#
#     accuracy                           0.82      1050
#    macro avg       0.82      0.81      0.82      1050
# weighted avg       0.82      0.82      0.82      1050

# %%
# !wget https://github.com/ivtipm/ML/blob/main/datasets/titanic.csv  -O toxic.csv
# Out:
# --2023-11-30 04:11:35--  https://github.com/ivtipm/ML/blob/main/datasets/titanic.csv
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89455 (87K) [text/plain]
# Saving to: ‘toxic.csv’
#
# toxic.csv           100%[===================>]  87.36K  --.-KB/s    in 0.07s
#
# 2023-11-30 04:11:36 (1.22 MB/s) - ‘toxic.csv’ saved [89455/89455]

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dataset = pd.read_csv("toxic.csv")

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/ivtipm/ML/main/datasets/titanic.csv'
dataset = pd.read_csv(url)

dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
